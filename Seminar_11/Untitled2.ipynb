# %% [markdown]
# Дана функция f(x) = 5x^2 + 10x - 30
#
# Определить корни
#
# Найти интервалы, на которых функция возрастает
#
# Найти интервалы, на которых функция убывает
#
# Построить график
#
# Вычислить вершину
#
# Определить промежутки, на котором f > 0
#
# Определить промежутки, на котором f < 0

# %%
import sympy

# %%
from sympy.plotting import plot

# %%
x = sympy.Symbol('x')

# %%
f = 5 * x ** 2 + 10 * x - 30

# %%
print(sympy.solve(f, x))
# Out:
# [-1 + sqrt(7), -sqrt(7) - 1]

# %%
print(f.diff(x))
# Out:
# 10*x + 10

# %%
plot (f.diff(x))

# %%
sympy.solve(f.diff(x))
# Out:
# [-1]

# %% [markdown]
# 2. возрастает от -1 до +оо

# %%
3. Функция убывает от -оо до -1
# Out:
#   Cell In[9], line 1
#     3. Функция убывает от -оо до -1
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 4.

# %%
plot (f)

# %%
f.subs(x, -1)
# Out:
# -35

# %%
5. Bершина (-1; -35)

# %%
1. Корни

# %%
print(sympy.solve(f, x))
# Out:
# [-1 + sqrt(7), -sqrt(7) - 1]

# %% [markdown]
# 6. y>0 при х=[-oo; -sqrt(7) - 1] & [-1 + sqrt(7); +oo]
# 7. y<0 при x = [-sqrt(7) - 1; -1 + sqrt(7)]
